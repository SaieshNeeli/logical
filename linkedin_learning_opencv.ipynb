# %% [markdown]
# <a href="https://colab.research.google.com/github/SaieshNeeli/logical/blob/main/linkedin_learning_opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
os.listdir()
# Out:
# ['.config',
#  'Install Instructions.pdf',
#  'Google Colab Cheat Sheet.pdf',
#  'opencv-logo.png',
#  'sample_data']

# %%
import numpy as np
import cv2
image = cv2.imread('opencv-logo.png')

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=600x739>
